# %%
import random
from time_moe.datasets.time_moe_dataset import TimeMoEDataset

ds = TimeMoEDataset('D:\data')
seq_idx = random.randint(0, len(ds) - 1)
seq = ds[seq_idx]
# Out:
# 正在遍历目录: D:\data
# 正在遍历目录: D:\data\.cache
# 正在遍历目录: D:\data\.cache\huggingface
# 正在遍历目录: D:\data\.cache\huggingface\download
# 正在遍历目录: D:\data\.cache\huggingface\download\energy
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\australian_electricity_demand
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\bdg-2_bear
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\bdg-2_fox
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\bdg-2_panther
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\bdg-2_rat
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\borealis
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\buildings_900k
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\bull
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\cockatoo
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\covid19_energy
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\elecdemand
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\electricity_15min
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\electricity_weekly
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\ercot
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\gfc12_load
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\gfc17_load
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\hog
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\ideal
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\kdd2022
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\kdd_cup_2018_with_missing
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\lcl
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\london_smart_meters
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\pdb
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\residential_load_power
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\residential_pv_power
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\sceaux
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\smart
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\solar_power
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\spain
# 正在遍历目录: D:\data\.cache\huggingface\download\energy\wind_farms_with_missing
# 正在遍历目录: D:\data\energy
# 正在遍历目录: D:\data\energy\australian_electricity_demand
# 正在遍历目录: D:\data\energy\bdg-2_bear
# 正在遍历目录: D:\data\energy\bdg-2_fox
# 正在遍历目录: D:\data\energy\bdg-2_panther
# 正在遍历目录: D:\data\energy\bdg-2_rat
# 正在遍历目录: D:\data\energy\borealis
# 正在遍历目录: D:\data\energy\buildings_900k
# 正在遍历目录: D:\data\energy\bull
# 正在遍历目录: D:\data\energy\cockatoo
# 正在遍历目录: D:\data\energy\covid19_energy
# 正在遍历目录: D:\data\energy\elecdemand
# 正在遍历目录: D:\data\energy\electricity_15min
# 正在遍历目录: D:\data\energy\electricity_weekly
# 正在遍历目录: D:\data\energy\ercot
# 正在遍历目录: D:\data\energy\gfc12_load
# 正在遍历目录: D:\data\energy\gfc17_load
# 正在遍历目录: D:\data\energy\hog
# 正在遍历目录: D:\data\energy\ideal
# 正在遍历目录: D:\data\energy\kdd2022
# 正在遍历目录: D:\data\energy\kdd_cup_2018_with_missing
# 正在遍历目录: D:\data\energy\lcl
# 正在遍历目录: D:\data\energy\london_smart_meters
# 正在遍历目录: D:\data\energy\pdb
# 正在遍历目录: D:\data\energy\residential_load_power
# 正在遍历目录: D:\data\energy\residential_pv_power
# 正在遍历目录: D:\data\energy\sceaux
# 正在遍历目录: D:\data\energy\smart
# 正在遍历目录: D:\data\energy\solar_power
# 正在遍历目录: D:\data\energy\spain
# 正在遍历目录: D:\data\energy\wind_farms_with_missing

# %%
len(seq)
# Out:
# 8761

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(12, 3))

ax.plot(seq[:1024])

# %%
ds.cumsum_lengths
# Out:
# [0,
#  5,
#  220,
#  399,
#  535,
#  990,
#  1007,
#  2467931,
#  2468395,
#  2468399,
#  2468400,
#  2468401,
#  2468748,
#  2469066,
#  2469218,
#  2469238,
#  2469246,
#  2469398,
#  2469623,
#  2478177,
#  2481231,
#  2482263,
#  2506395,
#  2506396,
#  2585904,
#  2834792,
#  2834793,
#  2834798,
#  2834824,
#  2834825,
#  2878071]

# %%
len(ds)
# Out:
# 2878071
